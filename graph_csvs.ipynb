# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('varyingOperationDistribution.csv')

# %%
df
# Out:
#      num_map                       Name  Threads  OperationsPerMilliSecond
# 0          0   splitOrderHash_MaxLoad_1        1             128544.617837
# 1          0   splitOrderHash_MaxLoad_1        2              90823.881595
# 2          0   splitOrderHash_MaxLoad_1        3             318679.392597
# 3          0   splitOrderHash_MaxLoad_1        4             202653.956211
# 4          0   splitOrderHash_MaxLoad_1        5             178667.462332
# ..       ...                        ...      ...                       ...
# 490        4  splitOrderHash_MaxLoad_16       95               9220.026340
# 491        4  splitOrderHash_MaxLoad_16       96               9652.753767
# 492        4  splitOrderHash_MaxLoad_16       97              12252.107699
# 493        4  splitOrderHash_MaxLoad_16       98               3930.719806
# 494        4  splitOrderHash_MaxLoad_16       99              11728.455297
#
# [495 rows x 4 columns]

# %%
df1 = df[df['Name'] == 'splitOrderHash_MaxLoad_1'];df1
# Out:
#     num_map                      Name  Threads  OperationsPerMilliSecond
# 0         0  splitOrderHash_MaxLoad_1        1             128544.617837
# 1         0  splitOrderHash_MaxLoad_1        2              90823.881595
# 2         0  splitOrderHash_MaxLoad_1        3             318679.392597
# 3         0  splitOrderHash_MaxLoad_1        4             202653.956211
# 4         0  splitOrderHash_MaxLoad_1        5             178667.462332
# ..      ...                       ...      ...                       ...
# 94        0  splitOrderHash_MaxLoad_1       95               9108.745671
# 95        0  splitOrderHash_MaxLoad_1       96               9266.321397
# 96        0  splitOrderHash_MaxLoad_1       97               5905.354645
# 97        0  splitOrderHash_MaxLoad_1       98              11156.737208
# 98        0  splitOrderHash_MaxLoad_1       99               9220.393593
#
# [99 rows x 4 columns]

# %%
df2 = df[df['Name'] == 'splitOrderHash_MaxLoad_2'];df2
# Out:
#      num_map                      Name  Threads  OperationsPerMilliSecond
# 99         1  splitOrderHash_MaxLoad_2        1             830344.094593
# 100        1  splitOrderHash_MaxLoad_2        2             594795.539033
# 101        1  splitOrderHash_MaxLoad_2        3             501441.644729
# 102        1  splitOrderHash_MaxLoad_2        4             323733.554335
# 103        1  splitOrderHash_MaxLoad_2        5             303531.590050
# ..       ...                       ...      ...                       ...
# 193        1  splitOrderHash_MaxLoad_2       95               8165.259629
# 194        1  splitOrderHash_MaxLoad_2       96               8274.786461
# 195        1  splitOrderHash_MaxLoad_2       97               3047.699669
# 196        1  splitOrderHash_MaxLoad_2       98               7109.030851
# 197        1  splitOrderHash_MaxLoad_2       99               5172.020095
#
# [99 rows x 4 columns]

# %%
df4 = df[df['Name'] == 'splitOrderHash_MaxLoad_4'];df4
# Out:
#      num_map                      Name  Threads  OperationsPerMilliSecond
# 198        2  splitOrderHash_MaxLoad_4        1             792116.853078
# 199        2  splitOrderHash_MaxLoad_4        2             500462.928209
# 200        2  splitOrderHash_MaxLoad_4        3             418303.278243
# 201        2  splitOrderHash_MaxLoad_4        4             323681.161109
# 202        2  splitOrderHash_MaxLoad_4        5             341840.606562
# ..       ...                       ...      ...                       ...
# 292        2  splitOrderHash_MaxLoad_4       95              12454.191925
# 293        2  splitOrderHash_MaxLoad_4       96              12984.379013
# 294        2  splitOrderHash_MaxLoad_4       97              12098.745118
# 295        2  splitOrderHash_MaxLoad_4       98              10682.685567
# 296        2  splitOrderHash_MaxLoad_4       99              10994.289456
#
# [99 rows x 4 columns]

# %%
df8 = df[df['Name'] == 'splitOrderHash_MaxLoad_8'];df8
# Out:
#      num_map                      Name  Threads  OperationsPerMilliSecond
# 297        3  splitOrderHash_MaxLoad_8        1             378617.214210
# 298        3  splitOrderHash_MaxLoad_8        2             684547.035227
# 299        3  splitOrderHash_MaxLoad_8        3             393669.789780
# 300        3  splitOrderHash_MaxLoad_8        4             403359.175211
# 301        3  splitOrderHash_MaxLoad_8        5             253639.730127
# ..       ...                       ...      ...                       ...
# 391        3  splitOrderHash_MaxLoad_8       95              12054.150135
# 392        3  splitOrderHash_MaxLoad_8       96              10479.178240
# 393        3  splitOrderHash_MaxLoad_8       97               9077.000650
# 394        3  splitOrderHash_MaxLoad_8       98              11128.212701
# 395        3  splitOrderHash_MaxLoad_8       99               5221.320280
#
# [99 rows x 4 columns]

# %%
df16 = df[df['Name'] == 'splitOrderHash_MaxLoad_16'];df16
# Out:
#      num_map                       Name  Threads  OperationsPerMilliSecond
# 396        4  splitOrderHash_MaxLoad_16        1             543788.575002
# 397        4  splitOrderHash_MaxLoad_16        2             497467.888448
# 398        4  splitOrderHash_MaxLoad_16        3             393997.060782
# 399        4  splitOrderHash_MaxLoad_16        4             249980.626501
# 400        4  splitOrderHash_MaxLoad_16        5             352662.780323
# ..       ...                        ...      ...                       ...
# 490        4  splitOrderHash_MaxLoad_16       95               9220.026340
# 491        4  splitOrderHash_MaxLoad_16       96               9652.753767
# 492        4  splitOrderHash_MaxLoad_16       97              12252.107699
# 493        4  splitOrderHash_MaxLoad_16       98               3930.719806
# 494        4  splitOrderHash_MaxLoad_16       99              11728.455297
#
# [99 rows x 4 columns]

# %%
import seaborn as sns


fig, axs = plt.subplots(ncols=1)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", data=df1,ax=axs, ci=99)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", data=df2,ax=axs, ci=99)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", data=df4,ax=axs, ci=99)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", data=df8,ax=axs, ci=99)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", data=df16,ax=axs, ci=99)

plt.title('Varying Max Loads for Split Ordered Hash Map')


axs.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

#axs.fill_between(x=df_LP["step"], y1=df_LP["reward"] + df_LP["reward_se"],y2=df_LP["reward"] - df_LP["reward_se"], alpha=.5)
axs.legend(['ML1', 'ML2', 'ML4', 'ML8', 'ML16'], loc=4)
