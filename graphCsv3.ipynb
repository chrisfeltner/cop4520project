# %%
import pandas as pd
import seaborn as snsj
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('varyingOperationDistribution.csv')

# %%
df[df['num_map'] == 0]
# Out:
#     num_map                       Name  Threads  OperationsPerMilliSecond  \
# 0         0  splitOrderHash_MaxLoad_16        1             900333.123256
# 1         0  splitOrderHash_MaxLoad_16        2             656439.341723
# 2         0  splitOrderHash_MaxLoad_16        3             378418.061137
# 3         0  splitOrderHash_MaxLoad_16        4             329563.131113
# 4         0  splitOrderHash_MaxLoad_16        5             297526.955942
# 5         0  splitOrderHash_MaxLoad_16        6             285388.127854
# 6         0  splitOrderHash_MaxLoad_16        7             265230.180012
# 7         0  splitOrderHash_MaxLoad_16        8             193287.137707
# 8         0  splitOrderHash_MaxLoad_16        9             188672.481553
# 9         0  splitOrderHash_MaxLoad_16       10             192820.520731
# 10        0  splitOrderHash_MaxLoad_16       11             106690.793011
# 11        0  splitOrderHash_MaxLoad_16       12             146419.744410
# 12        0  splitOrderHash_MaxLoad_16       13              30989.945932
# 13        0  splitOrderHash_MaxLoad_16       14              29986.661933
# 14        0  splitOrderHash_MaxLoad_16       15              16279.857258
# 15        0  splitOrderHash_MaxLoad_16       16              11361.540934
# 16        0  splitOrderHash_MaxLoad_16       17              10633.084268
# 17        0  splitOrderHash_MaxLoad_16       18              11268.138887
# 18        0  splitOrderHash_MaxLoad_16       19              14179.338860
# 19        0  splitOrderHash_MaxLoad_16       20              12709.577760
# 20        0  splitOrderHash_MaxLoad_16       21              12718.549190
# 21        0  splitOrderHash_MaxLoad_16       22               8954.729633
# 22        0  splitOrderHash_MaxLoad_16       23              16028.823672
# 23        0  splitOrderHash_MaxLoad_16       24              12571.950846
# 24        0  splitOrderHash_MaxLoad_16       25              12540.200749
# 25        0  splitOrderHash_MaxLoad_16       26              11441.965721
# 26        0  splitOrderHash_MaxLoad_16       27              13747.191621
# 27        0  splitOrderHash_MaxLoad_16       28              11922.259240
# 28        0  splitOrderHash_MaxLoad_16       29              10066.348308
# 29        0  splitOrderHash_MaxLoad_16       30               9959.199153
# 30        0  splitOrderHash_MaxLoad_16       31               7251.949777
#
#     LogOperationsPerMilliSecond
# 0                     13.710520
# 1                     13.394586
# 2                     12.843755
# 3                     12.705523
# 4                     12.603260
# 5                     12.561605
# 6                     12.488353
# 7                     12.171932
# 8                     12.147768
# 9                     12.169515
# 10                    11.577690
# 11                    11.894233
# 12                    10.341418
# 13                    10.308508
# 14                     9.697684
# 15                     9.337989
# 16                     9.271726
# 17                     9.329734
# 18                     9.559541
# 19                     9.450111
# 20                     9.450817
# 21                     9.099937
# 22                     9.682144
# 23                     9.439223
# 24                     9.436695
# 25                     9.345043
# 26                     9.528590
# 27                     9.386162
# 28                     9.216953
# 29                     9.206252
# 30                     8.889026

# %%
df16 = df[df['Name'] == 'splitOrderHash_MaxLoad_16'];df16
# Out:
#     num_map                       Name  Threads  OperationsPerMilliSecond  \
# 0         0  splitOrderHash_MaxLoad_16        1             900333.123256
# 1         0  splitOrderHash_MaxLoad_16        2             656439.341723
# 2         0  splitOrderHash_MaxLoad_16        3             378418.061137
# 3         0  splitOrderHash_MaxLoad_16        4             329563.131113
# 4         0  splitOrderHash_MaxLoad_16        5             297526.955942
# 5         0  splitOrderHash_MaxLoad_16        6             285388.127854
# 6         0  splitOrderHash_MaxLoad_16        7             265230.180012
# 7         0  splitOrderHash_MaxLoad_16        8             193287.137707
# 8         0  splitOrderHash_MaxLoad_16        9             188672.481553
# 9         0  splitOrderHash_MaxLoad_16       10             192820.520731
# 10        0  splitOrderHash_MaxLoad_16       11             106690.793011
# 11        0  splitOrderHash_MaxLoad_16       12             146419.744410
# 12        0  splitOrderHash_MaxLoad_16       13              30989.945932
# 13        0  splitOrderHash_MaxLoad_16       14              29986.661933
# 14        0  splitOrderHash_MaxLoad_16       15              16279.857258
# 15        0  splitOrderHash_MaxLoad_16       16              11361.540934
# 16        0  splitOrderHash_MaxLoad_16       17              10633.084268
# 17        0  splitOrderHash_MaxLoad_16       18              11268.138887
# 18        0  splitOrderHash_MaxLoad_16       19              14179.338860
# 19        0  splitOrderHash_MaxLoad_16       20              12709.577760
# 20        0  splitOrderHash_MaxLoad_16       21              12718.549190
# 21        0  splitOrderHash_MaxLoad_16       22               8954.729633
# 22        0  splitOrderHash_MaxLoad_16       23              16028.823672
# 23        0  splitOrderHash_MaxLoad_16       24              12571.950846
# 24        0  splitOrderHash_MaxLoad_16       25              12540.200749
# 25        0  splitOrderHash_MaxLoad_16       26              11441.965721
# 26        0  splitOrderHash_MaxLoad_16       27              13747.191621
# 27        0  splitOrderHash_MaxLoad_16       28              11922.259240
# 28        0  splitOrderHash_MaxLoad_16       29              10066.348308
# 29        0  splitOrderHash_MaxLoad_16       30               9959.199153
# 30        0  splitOrderHash_MaxLoad_16       31               7251.949777
#
#     LogOperationsPerMilliSecond
# 0                     13.710520
# 1                     13.394586
# 2                     12.843755
# 3                     12.705523
# 4                     12.603260
# 5                     12.561605
# 6                     12.488353
# 7                     12.171932
# 8                     12.147768
# 9                     12.169515
# 10                    11.577690
# 11                    11.894233
# 12                    10.341418
# 13                    10.308508
# 14                     9.697684
# 15                     9.337989
# 16                     9.271726
# 17                     9.329734
# 18                     9.559541
# 19                     9.450111
# 20                     9.450817
# 21                     9.099937
# 22                     9.682144
# 23                     9.439223
# 24                     9.436695
# 25                     9.345043
# 26                     9.528590
# 27                     9.386162
# 28                     9.216953
# 29                     9.206252
# 30                     8.889026

# %%
df16r = df[df['Name'] == 'Refinable16'];df16r
# Out:
#     num_map         Name  Threads  OperationsPerMilliSecond  \
# 31        1  Refinable16        1              1.273756e+06
# 32        1  Refinable16        2              7.327779e+05
# 33        1  Refinable16        3              5.356416e+05
# 34        1  Refinable16        4              3.829921e+05
# 35        1  Refinable16        5              3.005828e+05
# 36        1  Refinable16        6              2.705877e+05
# 37        1  Refinable16        7              2.219411e+05
# 38        1  Refinable16        8              2.072024e+05
# 39        1  Refinable16        9              1.718665e+05
# 40        1  Refinable16       10              1.507248e+05
# 41        1  Refinable16       11              1.316046e+05
# 42        1  Refinable16       12              1.267189e+05
# 43        1  Refinable16       13              1.204332e+05
# 44        1  Refinable16       14              1.103426e+05
# 45        1  Refinable16       15              8.095075e+04
# 46        1  Refinable16       16              9.614821e+04
# 47        1  Refinable16       17              8.822411e+04
# 48        1  Refinable16       18              8.998592e+04
# 49        1  Refinable16       19              9.188128e+04
# 50        1  Refinable16       20              1.218952e+05
# 51        1  Refinable16       21              6.825324e+04
# 52        1  Refinable16       22              6.949695e+04
# 53        1  Refinable16       23              6.715660e+04
# 54        1  Refinable16       24              5.720807e+04
# 55        1  Refinable16       25              6.847472e+04
# 56        1  Refinable16       26              6.411284e+04
# 57        1  Refinable16       27              5.994291e+04
# 58        1  Refinable16       28              4.981908e+04
# 59        1  Refinable16       29              5.401522e+04
# 60        1  Refinable16       30              5.453077e+04
# 61        1  Refinable16       31              5.221796e+04
#
#     LogOperationsPerMilliSecond
# 31                    14.057480
# 32                    13.504598
# 33                    13.191221
# 34                    12.855770
# 35                    12.613479
# 36                    12.508351
# 37                    12.310167
# 38                    12.241451
# 39                    12.054473
# 40                    11.923211
# 41                    11.787557
# 42                    11.749727
# 43                    11.698850
# 44                    11.611346
# 45                    11.301596
# 46                    11.473646
# 47                    11.387636
# 48                    11.407408
# 49                    11.428253
# 50                    11.710917
# 51                    11.130980
# 52                    11.149038
# 53                    11.114782
# 54                    10.954450
# 55                    11.134220
# 56                    11.068400
# 57                    11.001148
# 58                    10.816153
# 59                    10.897021
# 60                    10.906520
# 61                    10.863182

# %%
df1c = df[df['Name'] == 'concHashMap'];df1c
# Out:
#     num_map         Name  Threads  OperationsPerMilliSecond  \
# 62        2  concHashMap        1             131246.341508
# 63        2  concHashMap        2             679865.114761
# 64        2  concHashMap        3             408661.999747
# 65        2  concHashMap        4             468950.769548
# 66        2  concHashMap        5             324705.897633
# 67        2  concHashMap        6             287997.696018
# 68        2  concHashMap        7             251680.597188
# 69        2  concHashMap        8             214643.862903
# 70        2  concHashMap        9             199419.291025
# 71        2  concHashMap       10             164385.273052
# 72        2  concHashMap       11             143211.694094
# 73        2  concHashMap       12             132705.019302
# 74        2  concHashMap       13             136728.016528
# 75        2  concHashMap       14             106944.665760
# 76        2  concHashMap       15             112269.986864
# 77        2  concHashMap       16             103842.699079
# 78        2  concHashMap       17              83115.915950
# 79        2  concHashMap       18              98512.073640
# 80        2  concHashMap       19              92161.226850
# 81        2  concHashMap       20              84434.998983
# 82        2  concHashMap       21              82990.857727
# 83        2  concHashMap       22              33517.175038
# 84        2  concHashMap       23              66451.938303
# 85        2  concHashMap       24              66994.268640
# 86        2  concHashMap       25              59147.868488
# 87        2  concHashMap       26              63615.133531
# 88        2  concHashMap       27              54240.377079
# 89        2  concHashMap       28              54159.416075
# 90        2  concHashMap       29              47130.239704
# 91        2  concHashMap       30              10189.189820
# 92        2  concHashMap       31              20615.861762
#
#     LogOperationsPerMilliSecond
# 62                    11.784831
# 63                    13.429650
# 64                    12.920644
# 65                    13.058253
# 66                    12.690675
# 67                    12.570708
# 68                    12.435916
# 69                    12.276735
# 70                    12.203165
# 71                    12.009968
# 72                    11.872079
# 73                    11.795884
# 74                    11.825749
# 75                    11.580067
# 76                    11.628662
# 77                    11.550633
# 78                    11.327991
# 79                    11.497934
# 80                    11.431295
# 81                    11.343737
# 82                    11.326486
# 83                    10.419813
# 84                    11.104234
# 85                    11.112362
# 86                    10.987796
# 87                    11.060607
# 88                    10.901181
# 89                    10.899687
# 90                    10.760670
# 91                     9.229083
# 92                     9.933816

# %%
df1cs = df[df['Name'] == 'concSkipListSet'];df1cs
# Out:
#      num_map             Name  Threads  OperationsPerMilliSecond  \
# 93         3  concSkipListSet        1              1.080205e+06
# 94         3  concSkipListSet        2              8.953273e+05
# 95         3  concSkipListSet        3              4.458454e+05
# 96         3  concSkipListSet        4              3.188359e+05
# 97         3  concSkipListSet        5              3.161396e+05
# 98         3  concSkipListSet        6              2.436030e+05
# 99         3  concSkipListSet        7              2.390183e+05
# 100        3  concSkipListSet        8              1.995749e+05
# 101        3  concSkipListSet        9              1.783526e+05
# 102        3  concSkipListSet       10              1.930886e+05
# 103        3  concSkipListSet       11              8.329356e+04
# 104        3  concSkipListSet       12              1.145349e+05
# 105        3  concSkipListSet       13              3.967464e+04
# 106        3  concSkipListSet       14              3.065745e+04
# 107        3  concSkipListSet       15              2.317736e+04
# 108        3  concSkipListSet       16              2.340031e+04
# 109        3  concSkipListSet       17              2.538105e+04
# 110        3  concSkipListSet       18              3.926017e+04
# 111        3  concSkipListSet       19              2.626052e+04
# 112        3  concSkipListSet       20              2.693930e+04
# 113        3  concSkipListSet       21              2.906642e+04
# 114        3  concSkipListSet       22              4.148526e+04
# 115        3  concSkipListSet       23              1.695102e+04
# 116        3  concSkipListSet       24              1.766168e+04
# 117        3  concSkipListSet       25              1.833795e+04
# 118        3  concSkipListSet       26              2.171188e+04
# 119        3  concSkipListSet       27              1.615522e+04
# 120        3  concSkipListSet       28              1.381696e+04
# 121        3  concSkipListSet       29              1.450849e+04
# 122        3  concSkipListSet       30              1.488244e+04
# 123        3  concSkipListSet       31              1.674644e+04
#
#      LogOperationsPerMilliSecond
# 93                     13.892662
# 94                     13.704945
# 95                     13.007728
# 96                     12.672432
# 97                     12.663939
# 98                     12.403295
# 99                     12.384295
# 100                    12.203945
# 101                    12.091518
# 102                    12.170904
# 103                    11.330127
# 104                    11.648635
# 105                    10.588467
# 106                    10.330631
# 107                    10.050931
# 108                    10.060505
# 109                    10.141758
# 110                    10.577966
# 111                    10.175822
# 112                    10.201341
# 113                    10.277339
# 114                    10.633093
# 115                     9.738083
# 116                     9.779153
# 117                     9.816728
# 118                     9.985615
# 119                     9.689999
# 120                     9.533652
# 121                     9.582490
# 122                     9.607937
# 123                     9.725941

# %%
import seaborn as sns
palette = sns.color_palette('tab10', 5)

fig, axs = plt.subplots(ncols=1)
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='p',data=df16,ax=axs, ci=99 , color=palette[0])


sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='.',data=df16r,ax=axs, ci=99 , color=palette[1])
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='',data=df1c,ax=axs, ci=99 , color=palette[2])
sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='',data=df1cs,ax=axs, ci=99 , color=palette[3])


#sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='+',data=df1c,ax=axs, ci=99, color='black')
#sns.lineplot(x="Threads", y="OperationsPerMilliSecond", marker='+',data=df1cs,ax=axs, ci=99, color='black')


plt.title('33.33% Add/Remove/Find')


#axs.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

#axs.fill_between(x=df_LP["step"], y1=df_LP["reward"] + df_LP["reward_se"],y2=df_LP["reward"] - df_LP["reward_se"], alpha=.5)
axs.legend(['SplitOrderHash', 'RefinedHashSet', 'ConcurrentHashMap', 'SkipListSet'], loc=1)

# %%
palette = sns.color_palette('Greens', 5)

palette = sns.color_palette('tab10', 5)

fig, axs = plt.subplots(ncols=1)
sns.lineplot(x="Threads", y="LogOperationsPerMilliSecond", marker='p',data=df16,ax=axs, ci=99 , color=palette[0])


sns.lineplot(x="Threads", y="LogOperationsPerMilliSecond", marker='.',data=df16r,ax=axs, ci=99 , color=palette[1])
sns.lineplot(x="Threads", y="LogOperationsPerMilliSecond", marker='',data=df1c,ax=axs, ci=99 , color=palette[2])
sns.lineplot(x="Threads", y="LogOperationsPerMilliSecond", marker='',data=df1cs,ax=axs, ci=99 , color=palette[3])


plt.title('LogVarying Max Loads for Split Ordered Hash Map with Contractions')


#axs.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

#axs.fill_between(x=df_LP["step"], y1=df_LP["reward"] + df_LP["reward_se"],y2=df_LP["reward"] - df_LP["reward_se"], alpha=.5)
axs.legend(['SplitOrderHash', 'RefinedHashSet', 'ConcurrentHashMap', 'SkipListSet'], loc=1)
